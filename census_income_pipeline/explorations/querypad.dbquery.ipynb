-- %%
-- SELECT COUNT(*)
-- FROM census_income.dim_race_income;
SELECT fixed_fcc.fact_geo.geography_id, fixed_fcc.fact_geo.area_data_type, census_income.fact_geo.geography_desc
FROM fixed_fcc.fact_geo
INNER JOIN census_income.fact_geo ON fixed_fcc.fact_geo.geography_id = census_income.fact_geo.geography_id
LIMIT 180000;
