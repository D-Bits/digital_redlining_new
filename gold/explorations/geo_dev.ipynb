# %%
import pyspark.sql.functions as F

# %%
fcc_geo = spark.read.table("digital_redlining.silver_fcc.clean_geo")
census_geo = spark.read.table("digital_redlining.silver_census.clean_geo")

# %%
df = fcc_geo.join(census_geo, on="geo_id", how="inner")

# %%
display(df)

# %%
df.count()

# %%
df = df.drop_duplicates(["geo_id"])

# %%
df.count()

# %%
df = df.select(["id", "geo_id", "geography_desc", "geography_type", "area_data_type"]).orderBy("id")

display(df)

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS digital_redlining.gold_all;
