-- %%
  ALTER TABLE fcc_fixed.dim_tech SET TBLPROPERTIES (
    'delta.columnMapping.mode' = 'name'
  );

-- ALTER TABLE fcc_fixed.dim_technology RENAME TO fcc_fixed.dim_tech;
ALTER TABLE fcc_fixed.dim_tech DROP COLUMN fact_geo_id;
