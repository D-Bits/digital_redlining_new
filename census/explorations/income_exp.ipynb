# %%
import requests

# %%
# Fixed: Changed from acs1 to acs5 and use explicit variables instead of group()
response = requests.get("https://api.census.gov/data/2024/acs/acs5/subject?get=GEO_ID,NAME,S1903_C01_001E,S1903_C01_002E,S1903_C01_009E,S1903_C01_007E,S1903_C01_006E,S1903_C01_005E,S1903_C01_004E&ucgid=pseudo(0100000US$0400000)")
response.raise_for_status()  # Raise error if request failed
res = response.json()

df = spark.createDataFrame(res[1:], schema=res[0])

# %%
raw_county = spark.read.table("digital_redlining.bronze_census.raw_income_county")
raw_state = spark.read.table("digital_redlining.bronze_census.raw_income_state")
raw_msa = spark.read.table("digital_redlining.bronze_census.raw_income_msa")

# %%
raw_county.columns

# %%
raw_state.columns

# %%
raw_msa.columns
