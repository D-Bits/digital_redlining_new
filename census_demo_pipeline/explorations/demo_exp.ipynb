# %%
import pandas as pd

# %%
df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")

# %%
pd_df = df.toPandas()

pd_df.columns = pd_df.iloc[0]
pd_df.drop(pd_df.index[0], inplace=True)
pd_df.reset_index(drop=True)

display(pd_df)

# %%
len(pd_df.columns)

# %%
df = spark.createDataFrame(pd_df)

# %%
cols_to_drop = [col for col in df.columns if col.startswith("Margin")]
df = df.drop(*cols_to_drop)

# %%
[print(col) for col in df.columns]

# %%
# df = df.withColumnRenamed('Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)', 'hispanic')

# %%
df = df.select([
    'Geography', 
    'Geographic Area Name', 
    'Percent!!RACE!!Total population!!One race!!White', 
    'Percent!!RACE!!Total population!!One race!!Black or African American!!African American',
    'Percent!!HISPANIC OR LATINO AND RACE!!Total population',
    'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native',
    'Percent!!RACE!!Total population!!One race!!Asian',
    'Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander',
    'Percent!!RACE!!Total population!!One race!!Some Other Race',
])

display(df)

# %%
len(df.columns)

# %%
valid_columns = df.columns[df.columns.notnull()]
df = df.loc[:, ~valid_columns.str.lower().str.startswith("margin")]
display(pd_df)

# %%
len(pd_df.columns)
