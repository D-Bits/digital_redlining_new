# %%
from pyspark.sql.functions import monotonically_increasing_id
import pandas as pd

# %%
df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")

df.columns

# %%
df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")

df = df.withColumnRenamed('Geography', 'geography_id')
df = df.withColumnRenamed('Geographic Area Name', 'geography_name')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!White', 'percent_white')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!Black or African American!!African American', 'percent_black')
df = df.withColumnRenamed('Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)', 'percent_hispanic')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native', 'percent_native')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!Asian', 'percent_asian')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander', 'percent_hawaiian')
df = df.withColumnRenamed('Percent!!RACE!!Total population!!One race!!Some Other Race', 'percent_other')

df = df.withColumn("id", monotonically_increasing_id())


df = df.select(['id', 'geography_id', 'geography_name', 'percent_white', 'percent_black', 'percent_hispanic', 'percent_native', 'percent_asian', 'percent_hawaiian', 'percent_other'])

display(df)

# %%
df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")
pd_df = df.toPandas()

pd_df.columns = pd_df.iloc[0]
pd_df.drop(pd_df.index[0], inplace=True)
pd_df.reset_index(drop=True)

pd_df = pd_df.rename(columns={
    'Geography': 'geography_id',
    'Geographic Area Name': 'geography_name',
    'Percent!!RACE!!Total population!!One race!!White': 'percent_white',
    'Percent!!RACE!!Total population!!One race!!Black or African American!!African American': 'percent_black',
    'Percent!!HISPANIC OR LATINO AND RACE!!Total population': 'percent_hispanic',
    'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native': 'percent_native',
    'Percent!!RACE!!Total population!!One race!!Asian': 'percent_asian',
    'Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander': 'percent_hawaiian',
    'Percent!!RACE!!Total population!!One race!!Some Other Race': 'percent_other',
})

df = spark.createDataFrame(pd_df)
df = df.withColumn("id", monotonically_increasing_id())
df = df.select(['id', 'geography_id', 'geography_name', 'percent_white', 'percent_black', 'percent_hispanic', 'percent_native', 'percent_asian', 'percent_hawaiian', 'percent_other'])

display(df)
# pd_df.columns

# %%
df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")
pd_df = df.toPandas()

pd_df.columns = pd_df.iloc[0]
pd_df.drop(pd_df.index[0], inplace=True)
pd_df.reset_index(drop=True)

pd_df = pd_df.rename(columns={
    'Geography': 'geography_id',
    'Geographic Area Name': 'geography_name',
    'Percent!!RACE!!Total population!!One race!!White': 'percent_white',
    'Percent!!RACE!!Total population!!One race!!Black or African American!!African American': 'percent_black',
    'Percent!!HISPANIC OR LATINO AND RACE!!Total population': 'percent_hispanic',
    'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native': 'percent_native',
    'Percent!!RACE!!Total population!!One race!!Asian': 'percent_asian',
    'Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander': 'percent_hawaiian',
    'Percent!!RACE!!Total population!!One race!!Some Other Race': 'percent_other',
})

df = spark.createDataFrame(pd_df)
df = df.withColumn("id", monotonically_increasing_id())
df = df.select(['id', 'geography_id', 'geography_name', 'percent_white', 'percent_black', 'percent_hispanic', 'percent_native', 'percent_asian', 'percent_hawaiian', 'percent_other'])

display(df)
# pd_df.columns

# %%
# df = spark.read.format("csv").option("header", "true").load("/Volumes/digital_redlining/census_demo/src_files/ACSDP5Y2024.DP05-Data.csv")

# %%
# pd_df = df.toPandas()

# pd_df.columns = pd_df.iloc[0]
# pd_df.drop(pd_df.index[0], inplace=True)
# pd_df.reset_index(drop=True)

# pd_df = pd_df.rename(columns={
#     'Geography': 'geography_id',
#     'Geographic Area Name': 'geography_name',
#     'Percent!!RACE!!Total population!!One race!!White': 'percent_white',
#     'Percent!!RACE!!Total population!!One race!!Black or African American!!African American': 'percent_black',
#     'Percent!!HISPANIC OR LATINO AND RACE!!Total population': 'percent_hispanic',
#     'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native': 'percent_indian',
#     'Percent!!RACE!!Total population!!One race!!Asian': 'percent_asian',
#     'Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander': 'percent_hawaiian',
#     'Percent!!RACE!!Total population!!One race!!Some Other Race': 'percent_other',
# })

# display(pd_df)
# pd_df.columns

# %%
# len(pd_df.columns)

# %%
df = spark.createDataFrame(pd_df)

df = df.withColumn("id", monotonically_increasing_id())
df = df.select(['id', 'geography_id', 'geography_name', 'percent_white', 'percent_black', 'percent_hispanic', 'percent_native', 'percent_asian', 'percent_hawaiian', 'percent_other'])

df.head()

# %%
df = df.select(['id', 'geography_id', 'geography_name', 'percent_white', 'percent_black', 'percent_hispanic', 'percent_native', 'percent_asian', 'percent_hawaiian', 'percent_other'])

display(df)

# %%
# cols_to_drop = [col for col in df.columns if col.startswith("Margin")]
# df = df.drop(*cols_to_drop)

# %%
# [print(col) for col in df.columns]

# %%
# df = df.withColumnRenamed('Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)', 'hispanic')

# %%
df = df.select([
    'Geography', 
    'Geographic Area Name', 
    'Percent!!RACE!!Total population!!One race!!White', 
    'Percent!!RACE!!Total population!!One race!!Black or African American!!African American',
    'Percent!!HISPANIC OR LATINO AND RACE!!Total population',
    'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native',
    'Percent!!RACE!!Total population!!One race!!Asian',
    'Percent!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander',
    'Percent!!RACE!!Total population!!One race!!Some Other Race',
])

display(df)

# %%
# Add an id column
df = df.withColumn("id", monotonically_increasing_id())
# Rename columns
df = df.withColumnRenamed('Geography', 'geography_id')
df = df.withColumnRenamed('Geographic Area Name', 'geography_name')
fact_geo = df.select(['id', 'geography_id', 'geography_name'])

display(fact_geo)

# %%
len(df.columns)

# %%
valid_columns = df.columns[df.columns.notnull()]
df = df.loc[:, ~valid_columns.str.lower().str.startswith("margin")]
display(pd_df)

# %%
len(pd_df.columns)
