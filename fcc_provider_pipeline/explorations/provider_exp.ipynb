# %%
    mobile = spark.read.format('csv').option("header", "true").load('/Volumes/digital_redlining/provider_fcc/src_files/bdc_us_mobile_broadband_provider_summary_D24_30sep2025.csv')

# %%
fixed = spark.read.format('csv').option("header", "true").load('/Volumes/digital_redlining/provider_fcc/src_files/bdc_us_fixed_broadband_provider_summary_J25_17feb2026.csv')

# %%
provider_list = spark.read.format('csv').option('header', 'true').load('/Volumes/digital_redlining/provider_fcc/src_files/bdc_us_provider_list_D24_30sep2025.csv')

# %%
provider_geo = spark.read.format('csv').option('header', 'true').load('/Volumes/digital_redlining/provider_fcc/src_files/bdc_us_provider_summary_by_geography_J25_17feb2026.csv')
